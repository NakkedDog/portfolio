# %%
pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
import tensorflow_decision_forests as tfdf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
print("TensorFlow v" + tf.__version__)
print("TensorFlow Decision Forests v" + tfdf.__version__)
# Out:
# TensorFlow v2.16.1
# TensorFlow Decision Forests v1.9.0

# %%
train_file_path = "../content/drive/MyDrive/Colab Notebooks/coll_lb_single_house.csv"
dataset_df = pd.read_csv(train_file_path)
print("Full train dataset shape is {}".format(dataset_df.shape))
# Out:
# <ipython-input-18-a3f4304f10b9>:2: DtypeWarning: Columns (4,35,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset_df = pd.read_csv(train_file_path)
# Full train dataset shape is (274196, 132)

# %%
dataset_df.head(3)
# Out:
#        CLP  YEAR  COLL_ID DOCUMENT_TYPE_DESC DOCUMENT_NO BUILDING_STYLE_DESC  \
# 0  2482000  2020  1406643         โฉนด(Deed)      183675          บ้านเดี่ยว
# 1  4104400  2020  1404302         โฉนด(Deed)       71425          บ้านเดี่ยว
# 2  1598000  2007   751626         โฉนด(Deed)       91048          บ้านเดี่ยว
#
#   PROJECT_ID PROJECT_NAME PROVINCE_NAME     DISTICT_NAME  ...  \
# 0        NaN          NaN         ระยอง       เมืองระยอง  ...
# 1        NaN          NaN        นครปฐม        นครชัยศรี  ...
# 2        NaN          NaN    นครราชสีมา  เมืองนครราชสีมา  ...
#
#   CONVENIENCE_STORE_3KM_SHORTEST  DISCOUNT_STORE_3KM_SHORTEST  \
# 0                          1.373                        1.996
# 1                          2.733                        2.845
# 2                            NaN                          NaN
#
#    DEPARTMENT_STORE_3KM_SHORTEST  GAS_STATION_3KM_SHORTEST  \
# 0                            0.0                     1.301
# 1                            0.0                     2.588
# 2                            NaN                       NaN
#
#    MASS_TRANSIT_3KM_SHORTEST EDUCATION_3KM_SHORTEST BANK_3KM_SHORTEST  \
# 0                        0.0                  1.666             2.810
# 1                        0.0                  1.838             2.758
# 2                        NaN                    NaN               NaN
#
#   COFFEE_SHOP_3KM_SHORTEST  PHARMACY_3KM_SHORTEST  \
# 0                    1.314                    0.0
# 1                    2.713                    0.0
# 2                      NaN                    NaN
#
#   GOVERNMENT_OFFICE_3KM_SHORTEST
# 0                          0.967
# 1                          1.505
# 2                            NaN
#
# [3 rows x 132 columns]

# %% [markdown]
# # Data Cleaning
# 1. Drop unnecessary data column
# 2. Removing column with 50% null values

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274196 entries, 0 to 274195
# Columns: 132 entries, CLP to GOVERNMENT_OFFICE_3KM_SHORTEST
# dtypes: float64(58), int64(8), object(66)
# memory usage: 276.1+ MB

# %%
df_obj = dataset_df.select_dtypes(include = ['object'])
df_obj.info()
total_null_count = df_obj.isnull().sum().sum()
print("Total null values in df_obj:", total_null_count)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274196 entries, 0 to 274195
# Data columns (total 66 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   DOCUMENT_TYPE_DESC              274196 non-null  object
#  1   DOCUMENT_NO                     274196 non-null  object
#  2   BUILDING_STYLE_DESC             274196 non-null  object
#  3   PROJECT_ID                      34965 non-null   object
#  4   PROJECT_NAME                    35801 non-null   object
#  5   PROVINCE_NAME                   274196 non-null  object
#  6   DISTICT_NAME                    274195 non-null  object
#  7   SUBDISTICT_NAME                 273904 non-null  object
#  8   LAND_POSITION_DESC              107983 non-null  object
#  9   STREET                          243663 non-null  object
#  10  SOI                             230592 non-null  object
#  11  LAND_FILL_DESC                  260984 non-null  object
#  12  ROAD_THROUGH_LAND_DESC          273894 non-null  object
#  13  CAR_EXIST_DESC                  273897 non-null  object
#  14  NEED_TO_IMPROVE_WAY_CONDITIONS  1149 non-null    object
#  15  ROAD_SURFACE_DESC               260950 non-null  object
#  16  PU_ELECTRIC                     274196 non-null  object
#  17  PU_WATER                        274196 non-null  object
#  18  PU_ROAD_LIGHT                   274196 non-null  object
#  19  PU_DRAIN                        274196 non-null  object
#  20  PU_OTHER                        274196 non-null  object
#  21  ENTRY_EXIST_DESC                273863 non-null  object
#  22  EXPROPRIATION                   124493 non-null  object
#  23  EXPROPRIATION_BY_ROYAL_DECREE   271359 non-null  object
#  24  BY_ROYAL_DECREE                 1 non-null       object
#  25  ELEC_UTILITY_ALONG_STREET       271359 non-null  object
#  26  CAR_NOT_TO_LAND                 271356 non-null  object
#  27  LOCATE_HIGH_VOLTAGE             271782 non-null  object
#  28  LOCATE_IN_FOREST                124493 non-null  object
#  29  ADDITIONAL_CONDITION            127423 non-null  object
#  30  LAND_TYPE_DESC                  271847 non-null  object
#  31  LATITUDE                        195917 non-null  object
#  32  LONGITUDE                       195842 non-null  object
#  33  BUILDING_DESC                   260968 non-null  object
#  34  CLUB_DESC                       78685 non-null   object
#  35  SECURITY_SYSTEM_DESC            81410 non-null   object
#  36  OUTDOOR_STADIUM_DESC            79465 non-null   object
#  37  KEYCARD_DESC                    78895 non-null   object
#  38  KINDERGARTEN_DESC               78415 non-null   object
#  39  WASTE_DISPOSAL_SYS_DESC         88877 non-null   object
#  40  DEVELOPMENT_IN_AREA_DESC        104262 non-null  object
#  41  URBAN_PLANNING_TERMS_DESC       86782 non-null   object
#  42  PROJECT_REPUTATION              91816 non-null   object
#  43  LOCATION_DESC                   104931 non-null  object
#  44  PHYSICAL_APPEARANCE_DESC        104734 non-null  object
#  45  LAND_DIRECTION_DESC             105474 non-null  object
#  46  ENVIRONMENT_DESC                104982 non-null  object
#  47  POLLUTION_DESC                  25988 non-null   object
#  48  LIQUIDITY_DESC                  104631 non-null  object
#  49  CONSTRUCTION_SITE               108451 non-null  object
#  50  RESIDENTIAL_USE                 274073 non-null  object
#  51  STRUCTURE_DESC                  273923 non-null  object
#  52  MODEL_DESC                      274180 non-null  object
#  53  BUILDING_CONDITION_DESC         25224 non-null   object
#  54  ROOF_FRAME_DESC                 273845 non-null  object
#  55  ROOF_DESC                       273612 non-null  object
#  56  WALL_METERIAL_DESC              273852 non-null  object
#  57  PAINTING_DESC                   224593 non-null  object
#  58  FLOOR1_DESC                     273787 non-null  object
#  59  FLOOR1_SURFACE_DESC             259033 non-null  object
#  60  FLOOR2_DESC                     197122 non-null  object
#  61  FLOOR2_SURFACE_DESC             187228 non-null  object
#  62  FENCE_DESC                      273119 non-null  object
#  63  CONSTRUCTION_TYPE_DESC          260919 non-null  object
#  64  VILLAGE                         195333 non-null  object
#  65  UTILIZATION_OF_BUILDING_DESC    260916 non-null  object
# dtypes: object(66)
# memory usage: 138.1+ MB
# Total null values in df_obj: 5467935

# %%
dataset_df.drop([
        'COLL_ID','DOCUMENT_NO','PROJECT_ID','PROJECT_NAME','DISTICT_NAME','SUBDISTICT_NAME','STREET','SOI','LATITUDE','LONGITUDE','VILLAGE','PURCHASE_PRICE'
],
             axis=1,
             inplace=True)

# %%
dataset_df.info()
dataset_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274196 entries, 0 to 274195
# Columns: 120 entries, CLP to GOVERNMENT_OFFICE_3KM_SHORTEST
# dtypes: float64(58), int64(6), object(56)
# memory usage: 251.0+ MB
# (274196, 120)

# %%
df_new = dataset_df[(dataset_df['PROVINCE_NAME'] == 'กรุงเทพมหานคร') & (dataset_df['LAND_TYPE_DESC'] == 'จัดสรรโครงการใหม่')]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7221 entries, 94 to 274194
# Columns: 120 entries, CLP to GOVERNMENT_OFFICE_3KM_SHORTEST
# dtypes: float64(58), int64(6), object(56)
# memory usage: 6.7+ MB

# %%
df_new.head(10)
# Out:
#          CLP  YEAR DOCUMENT_TYPE_DESC BUILDING_STYLE_DESC  PROVINCE_NAME  WA  \
# 94   3197000  2017         โฉนด(Deed)          บ้านเดี่ยว  กรุงเทพมหานคร  42
# 109  2500000  2020         โฉนด(Deed)          บ้านเดี่ยว  กรุงเทพมหานคร  21
# 177  1600000  2012         โฉนด(Deed)          บ้านเดี่ยว  กรุงเทพมหานคร  50
# 210  2500000  2020         โฉนด(Deed)          บ้านเดี่ยว  กรุงเทพมหานคร  46
# 232  4650000  2020         โฉนด(Deed)          บ้านเดี่ยว  กรุงเทพมหานคร  51
# 454   940000  2008         โฉนด(Deed)          บ้านเดี่ยว  กรุงเทพมหานคร  25
# 576  5390000  2008         โฉนด(Deed)          บ้านเดี่ยว  กรุงเทพมหานคร   0
# 587  4950000  2020         โฉนด(Deed)          บ้านเดี่ยว  กรุงเทพมหานคร  51
# 614  2581000  2020         โฉนด(Deed)          บ้านเดี่ยว  กรุงเทพมหานคร  48
# 639  6031600  2020         โฉนด(Deed)          บ้านเดี่ยว  กรุงเทพมหานคร  60
#
#      DEVELOPER_CIF  LAND_AREA LAND_POSITION_DESC  DISTANCE  ...  \
# 94               0       42.0                NaN      80.0  ...
# 109              0       21.4            ถูกต้อง    1141.0  ...
# 177              0       50.0                NaN     380.0  ...
# 210              0       46.2            ถูกต้อง     780.0  ...
# 232        2464437       51.3                NaN       0.0  ...
# 454              0       25.0                NaN    2980.0  ...
# 576              0      100.0                NaN     950.0  ...
# 587        2464437       50.8                NaN       0.0  ...
# 614              0       47.5            ถูกต้อง     928.0  ...
# 639         573198       59.8                NaN       0.0  ...
#
#     CONVENIENCE_STORE_3KM_SHORTEST  DISCOUNT_STORE_3KM_SHORTEST  \
# 94                           0.201                        1.315
# 109                          1.143                        1.436
# 177                          0.147                        0.686
# 210                          0.281                        2.503
# 232                            NaN                          NaN
# 454                            NaN                          NaN
# 576                            NaN                          NaN
# 587                            NaN                          NaN
# 614                          0.319                        2.515
# 639                            NaN                          NaN
#
#      DEPARTMENT_STORE_3KM_SHORTEST  GAS_STATION_3KM_SHORTEST  \
# 94                             0.0                     0.795
# 109                            0.0                     1.664
# 177                            0.0                     0.599
# 210                            0.0                     1.762
# 232                            NaN                       NaN
# 454                            NaN                       NaN
# 576                            NaN                       NaN
# 587                            NaN                       NaN
# 614                            0.0                     1.710
# 639                            NaN                       NaN
#
#     MASS_TRANSIT_3KM_SHORTEST EDUCATION_3KM_SHORTEST BANK_3KM_SHORTEST  \
# 94                      1.963                  0.049             0.240
# 109                     0.000                  1.116             1.240
# 177                     0.000                  0.169             0.453
# 210                     0.000                  1.180             2.493
# 232                       NaN                    NaN               NaN
# 454                       NaN                    NaN               NaN
# 576                       NaN                    NaN               NaN
# 587                       NaN                    NaN               NaN
# 614                     0.000                  1.244             2.434
# 639                       NaN                    NaN               NaN
#
#     COFFEE_SHOP_3KM_SHORTEST PHARMACY_3KM_SHORTEST  \
# 94                     0.528                 0.492
# 109                    1.103                 1.423
# 177                    0.438                 1.652
# 210                    1.761                 0.000
# 232                      NaN                   NaN
# 454                      NaN                   NaN
# 576                      NaN                   NaN
# 587                      NaN                   NaN
# 614                    1.709                 0.000
# 639                      NaN                   NaN
#
#     GOVERNMENT_OFFICE_3KM_SHORTEST
# 94                           0.432
# 109                          1.221
# 177                          0.107
# 210                          1.929
# 232                            NaN
# 454                            NaN
# 576                            NaN
# 587                            NaN
# 614                          1.865
# 639                            NaN
#
# [10 rows x 120 columns]

# %%
# Check for null values in each column
null_counts = df_new.isnull().sum()

# Sort the null_counts Series in descending order
sorted_null_counts = null_counts.sort_values(ascending=False)

# Display the column names and null counts in descending order
print("Column names and null counts in descending order:")
for column, null_count in sorted_null_counts.items():
    print(f"{column}: {null_count}")
# Out:
# Column names and null counts in descending order:
# BY_ROYAL_DECREE: 7221
# NEED_TO_IMPROVE_WAY_CONDITIONS: 7140
# POLLUTION_DESC: 7017
# BUILDING_CONDITION_DESC: 6961
# KINDERGARTEN_DESC: 6499
# OUTDOOR_STADIUM_DESC: 6468
# KEYCARD_DESC: 6453
# CLUB_DESC: 6401
# SECURITY_SYSTEM_DESC: 6382
# WASTE_DISPOSAL_SYS_DESC: 6351
# LAND_DIRECTION_DESC: 6221
# URBAN_PLANNING_TERMS_DESC: 6218
# PROJECT_REPUTATION: 6216
# DEVELOPMENT_IN_AREA_DESC: 6214
# LOCATION_DESC: 6214
# PHYSICAL_APPEARANCE_DESC: 6214
# LIQUIDITY_DESC: 6212
# ENVIRONMENT_DESC: 6211
# LAND_POSITION_DESC: 6141
# CONSTRUCTION_SITE: 6067
# LOCATE_IN_FOREST: 4705
# EXPROPRIATION: 4705
# ADDITIONAL_CONDITION: 4662
# DEPARTMENT_STORE_1KM: 3157
# DISCOUNT_STORE_1KM: 3157
# EDUCATION_1KM: 3157
# BANK_1KM: 3157
# COFFEE_SHOP_1KM_SHORTEST: 3157
# BANK_1KM_SHORTEST: 3157
# MASS_TRANSIT_1KM_SHORTEST: 3157
# GAS_STATION_1KM_SHORTEST: 3157
# DEPARTMENT_STORE_1KM_SHORTEST: 3157
# CONVENIENCE_STORE_1KM: 3157
# DISCOUNT_STORE_1KM_SHORTEST: 3157
# CONVENIENCE_STORE_1KM_SHORTEST: 3157
# HOSPITAL_1KM_SHORTEST: 3157
# HOSPITAL_1KM: 3157
# GOVERNMENT_OFFICE_1KM: 3157
# PHARMACY_1KM: 3157
# COFFEE_SHOP_1KM: 3157
# EDUCATION_1KM_SHORTEST: 3157
# GOVERNMENT_OFFICE_3KM_SHORTEST: 3157
# MASS_TRANSIT_1KM: 3157
# BANK_3KM: 3157
# PHARMACY_3KM_SHORTEST: 3157
# COFFEE_SHOP_3KM_SHORTEST: 3157
# BANK_3KM_SHORTEST: 3157
# EDUCATION_3KM_SHORTEST: 3157
# MASS_TRANSIT_3KM_SHORTEST: 3157
# GAS_STATION_3KM_SHORTEST: 3157
# DEPARTMENT_STORE_3KM_SHORTEST: 3157
# DISCOUNT_STORE_3KM_SHORTEST: 3157
# CONVENIENCE_STORE_3KM_SHORTEST: 3157
# HOSPITAL_3KM_SHORTEST: 3157
# PHARMACY_3KM: 3157
# COFFEE_SHOP_3KM: 3157
# GOVERNMENT_OFFICE_3KM: 3157
# EDUCATION_3KM: 3157
# DISCOUNT_STORE_3KM: 3157
# PHARMACY_1KM_SHORTEST: 3157
# GOVERNMENT_OFFICE_1KM_SHORTEST: 3157
# HOSPITAL_3KM: 3157
# CONVENIENCE_STORE_3KM: 3157
# MASS_TRANSIT_3KM: 3157
# GAS_STATION_1KM: 3157
# DEPARTMENT_STORE_3KM: 3157
# GAS_STATION_3KM: 3157
# FLOOR2_SURFACE_DESC: 1801
# PAINTING_DESC: 1355
# ROAD_SURFACE_DESC: 1270
# FLOOR1_SURFACE_DESC: 1270
# LAND_FILL_DESC: 1269
# CONSTRUCTION_TYPE_DESC: 1269
# BUILDING_DESC: 1269
# UTILIZATION_OF_BUILDING_DESC: 1261
# FLOOR2_DESC: 547
# FENCE_DESC: 52
# ELEC_UTILITY_ALONG_STREET: 39
# CAR_NOT_TO_LAND: 39
# EXPROPRIATION_BY_ROYAL_DECREE: 39
# LOCATE_HIGH_VOLTAGE: 36
# STRUCTURE_DESC: 4
# WALL_METERIAL_DESC: 3
# ROOF_DESC: 3
# ROOF_FRAME_DESC: 1
# MODEL_DESC: 1
# FLOOR1_DESC: 1
# RESIDENTIAL_USE: 1
# FIRE_INSUR_AREA: 0
# LAND_FILL_AVERAGE: 0
# PU_ELECTRIC: 0
# CAR_EXIST_DESC: 0
# ROAD_THROUGH_LAND_DESC: 0
# PEDESTRIAN_ZONE: 0
# ROAD_SURFACE_WITH: 0
# DEVELOPER_CIF: 0
# DISTANCE: 0
# LAND_AREA: 0
# PU_ROAD_LIGHT: 0
# WA: 0
# PROVINCE_NAME: 0
# BUILDING_STYLE_DESC: 0
# DOCUMENT_TYPE_DESC: 0
# PU_WATER: 0
# ENTRY_EXIST_DESC: 0
# PU_DRAIN: 0
# PU_OTHER: 0
# ELEC_UTILITY_ALONG_STREET_DISTANCE: 0
# SPACE_IS_ENCROACHED: 0
# WELLS_OF_AREA: 0
# ESTIMATED_DEPTH: 0
# LAND_TYPE_DESC: 0
# SECTIONS_SCALE_ENCROACH: 0
# CONST_PROGRESS_PERC: 0
# CONST_PROGRESS_PERC_ADDED: 0
# BUILDING_AGE: 0
# BUILDING_AREA: 0
# YEAR: 0
# NO_OF_FLOOR: 0
# CLP: 0

# %%
df_new.drop([
'BY_ROYAL_DECREE',
'NEED_TO_IMPROVE_WAY_CONDITIONS',
'POLLUTION_DESC',
'BUILDING_CONDITION_DESC',
'KINDERGARTEN_DESC',
'OUTDOOR_STADIUM_DESC',
'KEYCARD_DESC',
'CLUB_DESC',
'SECURITY_SYSTEM_DESC',
'WASTE_DISPOSAL_SYS_DESC',
'LAND_DIRECTION_DESC',
'URBAN_PLANNING_TERMS_DESC',
'PROJECT_REPUTATION',
'DEVELOPMENT_IN_AREA_DESC',
'PHYSICAL_APPEARANCE_DESC',
'LOCATION_DESC',
'LIQUIDITY_DESC',
'ENVIRONMENT_DESC',
'LAND_POSITION_DESC',
'CONSTRUCTION_SITE',
'LOCATE_IN_FOREST',
'EXPROPRIATION',
'ADDITIONAL_CONDITION',
'HOSPITAL_1KM_SHORTEST',
'BANK_1KM',
'COFFEE_SHOP_1KM',
'PHARMACY_1KM',
'DISCOUNT_STORE_1KM',
'EDUCATION_1KM',
'CONVENIENCE_STORE_1KM',
'MASS_TRANSIT_1KM',
'BANK_1KM_SHORTEST',
'GAS_STATION_1KM',
'MASS_TRANSIT_1KM_SHORTEST',
'GAS_STATION_1KM_SHORTEST',
'DEPARTMENT_STORE_1KM',
'DEPARTMENT_STORE_1KM_SHORTEST',
'DISCOUNT_STORE_1KM_SHORTEST',
'CONVENIENCE_STORE_1KM_SHORTEST',
'HOSPITAL_1KM',
'EDUCATION_1KM_SHORTEST',
'GOVERNMENT_OFFICE_3KM_SHORTEST',
'GOVERNMENT_OFFICE_1KM',
'MASS_TRANSIT_3KM',
'HOSPITAL_3KM_SHORTEST',
'CONVENIENCE_STORE_3KM_SHORTEST',
'DISCOUNT_STORE_3KM_SHORTEST',
'COFFEE_SHOP_1KM_SHORTEST',
'GOVERNMENT_OFFICE_3KM',
'PHARMACY_3KM',
'DEPARTMENT_STORE_3KM_SHORTEST',
'GAS_STATION_3KM_SHORTEST',
'COFFEE_SHOP_3KM',
'MASS_TRANSIT_3KM_SHORTEST',
'EDUCATION_3KM',
'BANK_3KM',
'GAS_STATION_3KM',
'CONVENIENCE_STORE_3KM',
'PHARMACY_1KM_SHORTEST',
'GOVERNMENT_OFFICE_1KM_SHORTEST',
'HOSPITAL_3KM',
'PHARMACY_3KM_SHORTEST',
'COFFEE_SHOP_3KM_SHORTEST',
'BANK_3KM_SHORTEST',
'EDUCATION_3KM_SHORTEST',
'DISCOUNT_STORE_3KM',
'DEPARTMENT_STORE_3KM'

],
             axis=1,
             inplace=True)
# Out:
# <ipython-input-28-3089c0413cdc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop([

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7221 entries, 94 to 274194
# Data columns (total 53 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   CLP                                 7221 non-null   int64
#  1   YEAR                                7221 non-null   int64
#  2   DOCUMENT_TYPE_DESC                  7221 non-null   object
#  3   BUILDING_STYLE_DESC                 7221 non-null   object
#  4   PROVINCE_NAME                       7221 non-null   object
#  5   WA                                  7221 non-null   int64
#  6   DEVELOPER_CIF                       7221 non-null   int64
#  7   LAND_AREA                           7221 non-null   float64
#  8   DISTANCE                            7221 non-null   float64
#  9   LAND_FILL_DESC                      5952 non-null   object
#  10  LAND_FILL_AVERAGE                   7221 non-null   float64
#  11  ROAD_SURFACE_WITH                   7221 non-null   float64
#  12  PEDESTRIAN_ZONE                     7221 non-null   float64
#  13  ROAD_THROUGH_LAND_DESC              7221 non-null   object
#  14  CAR_EXIST_DESC                      7221 non-null   object
#  15  ROAD_SURFACE_DESC                   5951 non-null   object
#  16  PU_ELECTRIC                         7221 non-null   object
#  17  PU_WATER                            7221 non-null   object
#  18  PU_ROAD_LIGHT                       7221 non-null   object
#  19  PU_DRAIN                            7221 non-null   object
#  20  PU_OTHER                            7221 non-null   object
#  21  ENTRY_EXIST_DESC                    7221 non-null   object
#  22  EXPROPRIATION_BY_ROYAL_DECREE       7182 non-null   object
#  23  ELEC_UTILITY_ALONG_STREET           7182 non-null   object
#  24  ELEC_UTILITY_ALONG_STREET_DISTANCE  7221 non-null   float64
#  25  CAR_NOT_TO_LAND                     7182 non-null   object
#  26  LOCATE_HIGH_VOLTAGE                 7185 non-null   object
#  27  SPACE_IS_ENCROACHED                 7221 non-null   float64
#  28  WELLS_OF_AREA                       7221 non-null   float64
#  29  ESTIMATED_DEPTH                     7221 non-null   float64
#  30  LAND_TYPE_DESC                      7221 non-null   object
#  31  BUILDING_DESC                       5952 non-null   object
#  32  SECTIONS_SCALE_ENCROACH             7221 non-null   float64
#  33  CONST_PROGRESS_PERC                 7221 non-null   float64
#  34  CONST_PROGRESS_PERC_ADDED           7221 non-null   float64
#  35  RESIDENTIAL_USE                     7220 non-null   object
#  36  BUILDING_AGE                        7221 non-null   float64
#  37  BUILDING_AREA                       7221 non-null   float64
#  38  STRUCTURE_DESC                      7217 non-null   object
#  39  MODEL_DESC                          7220 non-null   object
#  40  NO_OF_FLOOR                         7221 non-null   int64
#  41  ROOF_FRAME_DESC                     7220 non-null   object
#  42  ROOF_DESC                           7218 non-null   object
#  43  WALL_METERIAL_DESC                  7218 non-null   object
#  44  PAINTING_DESC                       5866 non-null   object
#  45  FLOOR1_DESC                         7220 non-null   object
#  46  FLOOR1_SURFACE_DESC                 5951 non-null   object
#  47  FLOOR2_DESC                         6674 non-null   object
#  48  FLOOR2_SURFACE_DESC                 5420 non-null   object
#  49  FENCE_DESC                          7169 non-null   object
#  50  CONSTRUCTION_TYPE_DESC              5952 non-null   object
#  51  UTILIZATION_OF_BUILDING_DESC        5960 non-null   object
#  52  FIRE_INSUR_AREA                     7221 non-null   int64
# dtypes: float64(14), int64(6), object(33)
# memory usage: 3.0+ MB

# %%
# Check for null values in each column
null_counts = df_new.isnull().sum()

# Sort the null_counts Series in descending order
sorted_null_counts = null_counts.sort_values(ascending=False)

# Display the column names and null counts in descending order
print("Column names and null counts in descending order:")
for column, null_count in sorted_null_counts.items():
    print(f"{column}: {null_count}")
# Out:
# Column names and null counts in descending order:
# FLOOR2_SURFACE_DESC: 1801
# PAINTING_DESC: 1355
# FLOOR1_SURFACE_DESC: 1270
# ROAD_SURFACE_DESC: 1270
# BUILDING_DESC: 1269
# CONSTRUCTION_TYPE_DESC: 1269
# LAND_FILL_DESC: 1269
# UTILIZATION_OF_BUILDING_DESC: 1261
# FLOOR2_DESC: 547
# FENCE_DESC: 52
# EXPROPRIATION_BY_ROYAL_DECREE: 39
# CAR_NOT_TO_LAND: 39
# ELEC_UTILITY_ALONG_STREET: 39
# LOCATE_HIGH_VOLTAGE: 36
# STRUCTURE_DESC: 4
# ROOF_DESC: 3
# WALL_METERIAL_DESC: 3
# ROOF_FRAME_DESC: 1
# MODEL_DESC: 1
# FLOOR1_DESC: 1
# RESIDENTIAL_USE: 1
# SECTIONS_SCALE_ENCROACH: 0
# CONST_PROGRESS_PERC: 0
# NO_OF_FLOOR: 0
# CONST_PROGRESS_PERC_ADDED: 0
# BUILDING_AGE: 0
# BUILDING_AREA: 0
# ESTIMATED_DEPTH: 0
# LAND_TYPE_DESC: 0
# CLP: 0
# WELLS_OF_AREA: 0
# PEDESTRIAN_ZONE: 0
# DOCUMENT_TYPE_DESC: 0
# BUILDING_STYLE_DESC: 0
# PROVINCE_NAME: 0
# WA: 0
# DEVELOPER_CIF: 0
# LAND_AREA: 0
# DISTANCE: 0
# LAND_FILL_AVERAGE: 0
# ROAD_SURFACE_WITH: 0
# ROAD_THROUGH_LAND_DESC: 0
# SPACE_IS_ENCROACHED: 0
# CAR_EXIST_DESC: 0
# PU_ELECTRIC: 0
# PU_WATER: 0
# PU_ROAD_LIGHT: 0
# PU_DRAIN: 0
# PU_OTHER: 0
# ENTRY_EXIST_DESC: 0
# ELEC_UTILITY_ALONG_STREET_DISTANCE: 0
# YEAR: 0
# FIRE_INSUR_AREA: 0

# %%
FLOOR2_SURFACE_DESC: 1801
PAINTING_DESC: 1355
FLOOR1_SURFACE_DESC: 1270
ROAD_SURFACE_DESC: 1270
BUILDING_DESC: 1269
CONSTRUCTION_TYPE_DESC: 1269
LAND_FILL_DESC: 1269
UTILIZATION_OF_BUILDING_DESC: 1261
FLOOR2_DESC: 547
FENCE_DESC: 52
ELEC_UTILITY_ALONG_STREET: 38
CAR_NOT_TO_LAND: 38
EXPROPRIATION_BY_ROYAL_DECREE: 38
LOCATE_HIGH_VOLTAGE: 35
STRUCTURE_DESC: 4
ROOF_DESC: 3
WALL_METERIAL_DESC: 3
ROOF_FRAME_DESC: 1
MODEL_DESC: 1
FLOOR1_DESC: 1
RESIDENTIAL_USE: 1

# %%
df_new['FLOOR2_SURFACE_DESC'].fillna('อื่นๆ', inplace=True)
df_new['PAINTING_DESC'].fillna('ไม่ทาสี', inplace=True)
df_new['FLOOR1_SURFACE_DESC'].fillna('อื่นๆ', inplace=True)
df_new['ROAD_SURFACE_DESC'].fillna('อื่นๆ', inplace=True)
df_new.drop(['BUILDING_DESC','UTILIZATION_OF_BUILDING_DESC'], axis=1,inplace=True)
df_new['CONSTRUCTION_TYPE_DESC'].fillna('อื่นๆ', inplace=True)
df_new['LAND_FILL_DESC'].fillna('ถมแล้ว', inplace=True)
df_new['FLOOR2_DESC'].fillna('อื่นๆ', inplace=True)
df_new['FENCE_DESC'].fillna('อื่นๆ', inplace=True)
df_new['ELEC_UTILITY_ALONG_STREET'].fillna('N', inplace=True)
df_new['CAR_NOT_TO_LAND'].fillna('N', inplace=True)
df_new.drop(['EXPROPRIATION_BY_ROYAL_DECREE'], axis=1,inplace=True)
df_new['LOCATE_HIGH_VOLTAGE'].fillna('N', inplace=True)
df_new['STRUCTURE_DESC'].fillna('ตึก', inplace=True)
df_new['ROOF_DESC'].fillna('อื่นๆ', inplace=True)
df_new['WALL_METERIAL_DESC'].fillna('อื่นๆ', inplace=True)
df_new['ROOF_FRAME_DESC'].fillna('อื่นๆ', inplace=True)
df_new.drop(['MODEL_DESC'], axis=1,inplace=True)
df_new['FLOOR1_DESC'].fillna('อื่นๆ', inplace=True)
df_new['RESIDENTIAL_USE'].fillna('Y', inplace=True)
# Out:
# <ipython-input-32-320f3c4932a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['FLOOR2_SURFACE_DESC'].fillna('อื่นๆ', inplace=True)
# <ipython-input-32-320f3c4932a4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['PAINTING_DESC'].fillna('ไม่ทาสี', inplace=True)
# <ipython-input-32-320f3c4932a4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['FLOOR1_SURFACE_DESC'].fillna('อื่นๆ', inplace=True)
# <ipython-input-32-320f3c4932a4>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['ROAD_SURFACE_DESC'].fillna('อื่นๆ', inplace=True)
# <ipython-input-32-320f3c4932a4>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(['BUILDING_DESC','UTILIZATION_OF_BUILDING_DESC'], axis=1,inplace=True)
# <ipython-input-32-320f3c4932a4>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['CONSTRUCTION_TYPE_DESC'].fillna('อื่นๆ', inplace=True)
# <ipython-input-32-320f3c4932a4>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['LAND_FILL_DESC'].fillna('ถมแล้ว', inplace=True)
# <ipython-input-32-320f3c4932a4>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['FLOOR2_DESC'].fillna('อื่นๆ', inplace=True)
# <ipython-input-32-320f3c4932a4>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['FENCE_DESC'].fillna('อื่นๆ', inplace=True)
# <ipython-input-32-320f3c4932a4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['ELEC_UTILITY_ALONG_STREET'].fillna('N', inplace=True)
# <ipython-input-32-320f3c4932a4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['CAR_NOT_TO_LAND'].fillna('N', inplace=True)
# <ipython-input-32-320f3c4932a4>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(['EXPROPRIATION_BY_ROYAL_DECREE'], axis=1,inplace=True)
# <ipython-input-32-320f3c4932a4>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['LOCATE_HIGH_VOLTAGE'].fillna('N', inplace=True)
# <ipython-input-32-320f3c4932a4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['STRUCTURE_DESC'].fillna('ตึก', inplace=True)
# <ipython-input-32-320f3c4932a4>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['ROOF_DESC'].fillna('อื่นๆ', inplace=True)
# <ipython-input-32-320f3c4932a4>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['WALL_METERIAL_DESC'].fillna('อื่นๆ', inplace=True)
# <ipython-input-32-320f3c4932a4>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['ROOF_FRAME_DESC'].fillna('อื่นๆ', inplace=True)
# <ipython-input-32-320f3c4932a4>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.drop(['MODEL_DESC'], axis=1,inplace=True)
# <ipython-input-32-320f3c4932a4>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['FLOOR1_DESC'].fillna('อื่นๆ', inplace=True)
# <ipython-input-32-320f3c4932a4>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['RESIDENTIAL_USE'].fillna('Y', inplace=True)

# %%
list(set(df_new.dtypes.tolist()))
# Out:
# [dtype('O'), dtype('float64'), dtype('int64')]

# %%
from sklearn.preprocessing import OneHotEncoder

s = (df_new.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print('No. of. categorical features: ',
      len(object_cols))
# Out:
# Categorical variables:
# ['DOCUMENT_TYPE_DESC', 'BUILDING_STYLE_DESC', 'PROVINCE_NAME', 'LAND_FILL_DESC', 'ROAD_THROUGH_LAND_DESC', 'CAR_EXIST_DESC', 'ROAD_SURFACE_DESC', 'PU_ELECTRIC', 'PU_WATER', 'PU_ROAD_LIGHT', 'PU_DRAIN', 'PU_OTHER', 'ENTRY_EXIST_DESC', 'ELEC_UTILITY_ALONG_STREET', 'CAR_NOT_TO_LAND', 'LOCATE_HIGH_VOLTAGE', 'LAND_TYPE_DESC', 'RESIDENTIAL_USE', 'STRUCTURE_DESC', 'ROOF_FRAME_DESC', 'ROOF_DESC', 'WALL_METERIAL_DESC', 'PAINTING_DESC', 'FLOOR1_DESC', 'FLOOR1_SURFACE_DESC', 'FLOOR2_DESC', 'FLOOR2_SURFACE_DESC', 'FENCE_DESC', 'CONSTRUCTION_TYPE_DESC']
# No. of. categorical features:  29

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# Assuming dataset_df and object_cols are defined
OH_encoder = OneHotEncoder(sparse_output=False)
OH_cols = pd.DataFrame(OH_encoder.fit_transform(df_new[object_cols]))
OH_cols.index = df_new.index
OH_cols.columns = OH_encoder.get_feature_names_out(object_cols)

df_final = df_new.drop(object_cols, axis=1)
df_final = pd.concat([df_final, OH_cols], axis=1)

# %%
print("Full train dataset shape is {}".format(df_final.shape))
# Out:
# Full train dataset shape is (7221, 111)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost
import math
from __future__ import division
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score

# %%
# Importing required libraries
import pandas as pd
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Assuming df_final is your DataFrame with features and target variable CLP
# Splitting the data into features (X) and target variable (y)
X = df_final.drop('CLP', axis=1)  # Features
y = df_final['CLP']  # Target variable

# Splitting dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Instantiate the XGBoost Regressor
xgb_regressor = XGBRegressor(random_state=42)

# Fit the model to the training data
xgb_regressor.fit(X_train, y_train)

# Predict on the test data
y_pred = xgb_regressor.predict(X_test)

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Percentage Error (MAPE): 21.831481938585455

# %%
import matplotlib.pyplot as plt

# Create a DataFrame for predicted and actual prices
results_df = pd.DataFrame({'Actual Price': y_test, 'Predicted Price': y_pred})

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(results_df['Actual Price'], results_df['Predicted Price'], color='blue', alpha=0.6)
plt.plot(results_df['Actual Price'], results_df['Actual Price'], color='red', linestyle='--', alpha=0.6)
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.xlim(0, 15000000)
plt.ylim(0, 15000000)
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a function to plot distributions of actual and predicted values
def plot_distributions(actual, predicted, model_name):
    plt.figure(figsize=(10, 5))
    sns.histplot(actual, color='blue', alpha=0.5, label='Actual Values', kde=True, stat='frequency')
    sns.histplot(predicted, color='orange', alpha=0.5, label='Predicted Values', kde=True, stat='frequency')
    plt.title(f'Actual vs. Predicted Values ({model_name})')
    plt.xlabel('Price')
    plt.ylabel('Frequency')
    plt.xlim(0, 15000000)  # Set x-axis limits from 0 to 15,000,000
    plt.gca().ticklabel_format(style='plain')  # Set tick labels without scientific notation
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot distributions for each model
models = [xgb_regressor]  # Add other models if you have trained them
model_names = ['xgboost']  # Adjust model names accordingly

for model, model_name in zip(models, model_names):
    predictions = model.predict(X_test)
    plot_distributions(y_test, predictions, model_name)

# %%
import matplotlib as mpl

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New', size= 15)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'xgb' is your XGBoost model
feature_importances = xgb_regressor.feature_importances_

# Get the names of the features
feature_names = X_test.columns  # Assuming X_test is a pandas DataFrame

# Create a DataFrame with feature names and their corresponding importances
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df.head(10))  # Plotting top 10 features
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 10 Most Important Features')
plt.show()

# %%
# Importing required libraries
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Assuming df_final is your DataFrame with features and target variable CLP
# Splitting the data into features (X) and target variable (y)
X = df_final.drop('CLP', axis=1)  # Features
y = df_final['CLP']  # Target variable

# Splitting dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Instantiate the KNN Regressor
knn_regressor = KNeighborsRegressor()

# Fit the model to the training data
knn_regressor.fit(X_train, y_train)

# Predict on the test data
y_pred = knn_regressor.predict(X_test)

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Percentage Error (MAPE): 33.1679840289367

# %%
import matplotlib.pyplot as plt

# Create a DataFrame for predicted and actual prices
results_df = pd.DataFrame({'Actual Price': y_test, 'Predicted Price': y_pred})

# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(results_df['Actual Price'], results_df['Predicted Price'], color='blue', alpha=0.6)
plt.plot(results_df['Actual Price'], results_df['Actual Price'], color='red', linestyle='--', alpha=0.6)
plt.title('Actual vs Predicted Prices')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.xlim(0, 15000000)
plt.ylim(0, 15000000)
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a function to plot distributions of actual and predicted values
def plot_distributions(actual, predicted, model_name):
    plt.figure(figsize=(10, 5))
    sns.histplot(actual, color='blue', alpha=0.5, label='Actual Values', kde=True, stat='frequency')
    sns.histplot(predicted, color='orange', alpha=0.5, label='Predicted Values', kde=True, stat='frequency')
    plt.title(f'Actual vs. Predicted Values ({model_name})')
    plt.xlabel('Price')
    plt.ylabel('Frequency')
    plt.xlim(0, 15000000)  # Set x-axis limits from 0 to 15,000,000
    plt.gca().ticklabel_format(style='plain')  # Set tick labels without scientific notation
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot distributions for each model
models = [knn_regressor]  # Add other models if you have trained them
model_names = ['KNeighborsRegressor']  # Adjust model names accordingly

for model, model_name in zip(models, model_names):
    predictions = model.predict(X_test)
    plot_distributions(y_test, predictions, model_name)

# %%
# Importing required libraries
import pandas as pd
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import train_test_split

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# Assuming df_final is your DataFrame with features and target variable CLP
# Splitting the data into features (X) and target variable (y)
X = df_final.drop('CLP', axis=1)  # Features
y = df_final['CLP']  # Target variable

# Splitting dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Instantiate the Extra Trees Regressor
extra_trees = ExtraTreesRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
extra_trees.fit(X_train, y_train)

# Predict on the test data
y_pred = extra_trees.predict(X_test)

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%')
# Out:
# Mean Absolute Percentage Error (MAPE): 22.47%

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a function to plot scatter plot of actual vs predicted values
def plot_scatter(actual, predicted, model_name):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=actual, y=predicted, color='blue', alpha=0.5)
    plt.title(f'Actual vs. Predicted Values ({model_name})')
    plt.xlabel('Actual Price')
    plt.ylabel('Predicted Price')
    plt.xlim(0, 20000000)  # Set x-axis limits from 0 to 15,000,000
    plt.ylim(0, 20000000)  # Set y-axis limits from 0 to 15,000,000
    plt.gca().ticklabel_format(style='plain')  # Set tick labels without scientific notation
    plt.plot([0, 20000000], [0, 20000000], color='red', linestyle='--', alpha=0.5)  # Add diagonal line for perfect predictions
    plt.grid(True)
    plt.show()

# Plot scatter plot for each model
models = [extra_trees]  # Add other models if you have trained them
model_names = ['ExtraTreesRegressor']  # Adjust model names accordingly

for model, model_name in zip(models, model_names):
    predictions = model.predict(X_test)
    plot_scatter(y_test, predictions, model_name)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a function to plot distributions of actual and predicted values
def plot_distributions(actual, predicted, model_name):
    plt.figure(figsize=(10, 5))
    sns.histplot(actual, color='blue', alpha=0.5, label='Actual Values', kde=True, stat='frequency')
    sns.histplot(predicted, color='orange', alpha=0.5, label='Predicted Values', kde=True, stat='frequency')
    plt.title(f'Actual vs. Predicted Values ({model_name})')
    plt.xlabel('Price')
    plt.ylabel('Frequency')
    plt.xlim(0, 15000000)  # Set x-axis limits from 0 to 15,000,000
    plt.gca().ticklabel_format(style='plain')  # Set tick labels without scientific notation
    plt.legend()
    plt.grid(True)
    plt.show()

# Plot distributions for each model
models = [extra_trees]  # Add other models if you have trained them
model_names = ['ExtraTreesRegressor']  # Adjust model names accordingly

for model, model_name in zip(models, model_names):
    predictions = model.predict(X_test)
    plot_distributions(y_test, predictions, model_name)

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Get feature importances
feature_importances = extra_trees.feature_importances_

# Get the names of the features
feature_names = X_train.columns  # Assuming X_train is a pandas DataFrame

# Create a DataFrame with feature names and their corresponding importances
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df.head(10))  # Plotting top 10 features
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 10 Most Important Features')
plt.show()
