# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost
import math
from __future__ import division
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score

# %%
train_file_path = "../content/drive/MyDrive/Colab Notebooks/coll_u.csv"
dataset_df = pd.read_csv(train_file_path)
print("Full train dataset shape is {}".format(dataset_df.shape))
# Out:
# Full train dataset shape is (237362, 97)

# %%
dataset_df.head(3)
# Out:
#    YEAR     CLP  COLL_ID                BUILDING_NAME PROJECT_ID PROJECT_NAME  \
# 0  2008  350000      340  อาคารชุดเคหะชุมชนแหลมฉบัง 3        NaN          NaN
# 1  2010  350000      541          เคหะชุมชนแหลมฉบัง 2        NaN          NaN
# 2  2008  350000      222        นิรันดร์ แกรนด์ วิลล์        NaN          NaN
#
#   PROVINCE_NAME DISTICT_NAME SUBDISTICT_NAME  INTERIOR_SPACE  ...  \
# 0        ชลบุรี     บางละมุง        บางละมุง               0  ...
# 1        ชลบุรี     บางละมุง        บางละมุง               0  ...
# 2        ชลบุรี     บางละมุง        หนองปรือ               0  ...
#
#    CONVENIENCE_STORE_3KM_SHORTEST  DISCOUNT_STORE_3KM_SHORTEST  \
# 0                           0.089                        0.875
# 1                           0.076                        0.261
# 2                           0.332                        0.617
#
#    DEPARTMENT_STORE_3KM_SHORTEST GAS_STATION_3KM_SHORTEST  \
# 0                          2.409                    0.043
# 1                          0.000                    0.438
# 2                          1.028                    0.649
#
#   MASS_TRANSIT_3KM_SHORTEST  EDUCATION_3KM_SHORTEST  BANK_3KM_SHORTEST  \
# 0                     0.681                   0.079              0.079
# 1                     0.539                   0.047              0.077
# 2                     0.000                   0.492              0.477
#
#    COFFEE_SHOP_3KM_SHORTEST PHARMACY_3KM_SHORTEST  \
# 0                     0.073                 0.802
# 1                     0.064                 0.694
# 2                     0.471                 0.588
#
#   GOVERNMENT_OFFICE_3KM_SHORTEST
# 0                          0.175
# 1                          0.152
# 2                          0.554
#
# [3 rows x 97 columns]

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237362 entries, 0 to 237361
# Data columns (total 97 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   YEAR                            237362 non-null  int64
#  1   CLP                             237362 non-null  int64
#  2   COLL_ID                         237362 non-null  int64
#  3   BUILDING_NAME                   237361 non-null  object
#  4   PROJECT_ID                      163960 non-null  object
#  5   PROJECT_NAME                    165884 non-null  object
#  6   PROVINCE_NAME                   237362 non-null  object
#  7   DISTICT_NAME                    237361 non-null  object
#  8   SUBDISTICT_NAME                 236828 non-null  object
#  9   INTERIOR_SPACE                  237362 non-null  int64
#  10  FIRE_INSUR_AREA                 237362 non-null  int64
#  11  BUILDING_AREA                   237362 non-null  float64
#  12  OUTSIDE_LIVING_SPACE            237362 non-null  int64
#  13  STREET                          94753 non-null   object
#  14  SOI                             88865 non-null   object
#  15  DISTANCE                        237362 non-null  float64
#  16  ROAD_SURFACE_WITH               237362 non-null  float64
#  17  PEDESTRIAN_ZONE                 237362 non-null  float64
#  18  ROAD_SURFACE_DESC               173852 non-null  object
#  19  PU_ELECTRIC                     237362 non-null  object
#  20  PU_WATER                        237362 non-null  object
#  21  PU_ROAD_LIGHT                   237362 non-null  object
#  22  PU_DRAIN                        237362 non-null  object
#  23  PU_OTHER                        237362 non-null  object
#  24  OTHER_PUBLIC_UTILITY            44092 non-null   object
#  25  BUILDING_AGE                    237362 non-null  int64
#  26  NO_OF_FLOOR                     237362 non-null  int64
#  27  BUILDING_CONDITION_DESC         237051 non-null  object
#  28  ROOF_DESC                       173083 non-null  object
#  29  EXPROPRIATION                   10 non-null      float64
#  30  SPACE_DIVISION                  138414 non-null  object
#  31  CONDO_FLOOR_DESC                46227 non-null   object
#  32  DECORATION                      141614 non-null  object
#  33  CONDO_BATHROOM_FLOOR_DESC       46035 non-null   object
#  34  LIFT                            170638 non-null  object
#  35  PARKING                         173441 non-null  object
#  36  FIRE_ESCAPE                     173334 non-null  object
#  37  FIRE_SPRINKLER                  173408 non-null  object
#  38  POOL                            167038 non-null  object
#  39  STEAM_ROOM                      162555 non-null  object
#  40  EXERCISE_ROOM                   167125 non-null  object
#  41  STADIUM                         163981 non-null  object
#  42  GARDEN                          168120 non-null  object
#  43  DEVELOPMENT_IN_AREA_DESC        47162 non-null   object
#  44  DIFF_RATING_AFFECTS_PRICE       137604 non-null  object
#  45  URBAN_PLANNING_TERMS_DESC       44909 non-null   object
#  46  LOCATION_DESC                   47162 non-null   object
#  47  PROJECT_REPUTATION              46957 non-null   object
#  48  ENVIRONMENT_DESC                47135 non-null   object
#  49  POLLUTION_DESC                  9795 non-null    object
#  50  LIQUIDITY_DESC                  46989 non-null   object
#  51  LAND_DIRECTION_DESC             45778 non-null   object
#  52  PHYSICAL_APPEARANCE_DESC        46679 non-null   object
#  53  HOSPITAL_1KM                    8 non-null       float64
#  54  CONVENIENCE_STORE_1KM           8 non-null       float64
#  55  DISCOUNT_STORE_1KM              8 non-null       float64
#  56  DEPARTMENT_STORE_1KM            8 non-null       float64
#  57  GAS_STATION_1KM                 8 non-null       float64
#  58  MASS_TRANSIT_1KM                8 non-null       float64
#  59  EDUCATION_1KM                   8 non-null       float64
#  60  BANK_1KM                        8 non-null       float64
#  61  COFFEE_SHOP_1KM                 8 non-null       float64
#  62  PHARMACY_1KM                    8 non-null       float64
#  63  GOVERNMENT_OFFICE_1KM           8 non-null       float64
#  64  HOSPITAL_1KM_SHORTEST           8 non-null       float64
#  65  CONVENIENCE_STORE_1KM_SHORTEST  8 non-null       float64
#  66  DISCOUNT_STORE_1KM_SHORTEST     8 non-null       float64
#  67  DEPARTMENT_STORE_1KM_SHORTEST   8 non-null       float64
#  68  GAS_STATION_1KM_SHORTEST        8 non-null       float64
#  69  MASS_TRANSIT_1KM_SHORTEST       8 non-null       float64
#  70  EDUCATION_1KM_SHORTEST          8 non-null       float64
#  71  BANK_1KM_SHORTEST               8 non-null       float64
#  72  COFFEE_SHOP_1KM_SHORTEST        8 non-null       float64
#  73  PHARMACY_1KM_SHORTEST           8 non-null       float64
#  74  GOVERNMENT_OFFICE_1KM_SHORTEST  8 non-null       float64
#  75  HOSPITAL_3KM                    8 non-null       float64
#  76  CONVENIENCE_STORE_3KM           8 non-null       float64
#  77  DISCOUNT_STORE_3KM              8 non-null       float64
#  78  DEPARTMENT_STORE_3KM            8 non-null       float64
#  79  GAS_STATION_3KM                 8 non-null       float64
#  80  MASS_TRANSIT_3KM                8 non-null       float64
#  81  EDUCATION_3KM                   8 non-null       float64
#  82  BANK_3KM                        8 non-null       float64
#  83  COFFEE_SHOP_3KM                 8 non-null       float64
#  84  PHARMACY_3KM                    8 non-null       float64
#  85  GOVERNMENT_OFFICE_3KM           8 non-null       float64
#  86  HOSPITAL_3KM_SHORTEST           8 non-null       float64
#  87  CONVENIENCE_STORE_3KM_SHORTEST  8 non-null       float64
#  88  DISCOUNT_STORE_3KM_SHORTEST     8 non-null       float64
#  89  DEPARTMENT_STORE_3KM_SHORTEST   8 non-null       float64
#  90  GAS_STATION_3KM_SHORTEST        8 non-null       float64
#  91  MASS_TRANSIT_3KM_SHORTEST       8 non-null       float64
#  92  EDUCATION_3KM_SHORTEST          8 non-null       float64
#  93  BANK_3KM_SHORTEST               8 non-null       float64
#  94  COFFEE_SHOP_3KM_SHORTEST        8 non-null       float64
#  95  PHARMACY_3KM_SHORTEST           8 non-null       float64
#  96  GOVERNMENT_OFFICE_3KM_SHORTEST  8 non-null       float64
# dtypes: float64(49), int64(8), object(40)
# memory usage: 175.7+ MB

# %%
dataset_df.drop([
        'COLL_ID','BUILDING_NAME','PROJECT_ID','PROJECT_NAME','SUBDISTICT_NAME','STREET','SOI'
],
             axis=1,
             inplace=True)

# %%
df_new = dataset_df[(dataset_df['PROVINCE_NAME'] == 'กรุงเทพมหานคร') & (dataset_df['NO_OF_FLOOR'] <= 7)]

# %%
df_new.shape
# Out:
# (30506, 90)

# %%
df_new.shape
# Out:
# (30506, 90)

# %%
df_new = df_new[['LIFT',
'FIRE_INSUR_AREA',
'BUILDING_CONDITION_DESC',
'BUILDING_AREA',
'NO_OF_FLOOR',
'GARDEN',
'POOL',
'BUILDING_AGE',
'DISTICT_NAME',
'STEAM_ROOM',
'EXERCISE_ROOM',
'CLP']]

# %%
# Check for null values in each column
null_counts = df_new.isnull().sum()

# Sort the null_counts Series in descending order
sorted_null_counts = null_counts.sort_values(ascending=False)

# Display the column names and null counts in descending order
print("Column names and null counts in descending order:")
for column, null_count in sorted_null_counts.items():
    print(f"{column}: {null_count}")
# Out:
# Column names and null counts in descending order:
# STEAM_ROOM: 8478
# POOL: 8334
# EXERCISE_ROOM: 8326
# LIFT: 7917
# GARDEN: 7761
# BUILDING_CONDITION_DESC: 18
# FIRE_INSUR_AREA: 0
# BUILDING_AREA: 0
# NO_OF_FLOOR: 0
# BUILDING_AGE: 0
# DISTICT_NAME: 0
# CLP: 0

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30506 entries, 33 to 237359
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   LIFT                     22589 non-null  object
#  1   FIRE_INSUR_AREA          30506 non-null  int64
#  2   BUILDING_CONDITION_DESC  30488 non-null  object
#  3   BUILDING_AREA            30506 non-null  float64
#  4   NO_OF_FLOOR              30506 non-null  int64
#  5   GARDEN                   22745 non-null  object
#  6   POOL                     22172 non-null  object
#  7   BUILDING_AGE             30506 non-null  int64
#  8   DISTICT_NAME             30506 non-null  object
#  9   STEAM_ROOM               22028 non-null  object
#  10  EXERCISE_ROOM            22180 non-null  object
#  11  CLP                      30506 non-null  int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 3.0+ MB

# %%
# Check for null values in each column
null_counts = df_new.isnull().sum()

# Sort the null_counts Series in descending order
sorted_null_counts = null_counts.sort_values()

# Display the column names and null counts in descending order
print("Column names and null counts in descending order:")
for column, null_count in sorted_null_counts.items():
    print(f"{column}: {null_count}")
# Out:
# Column names and null counts in descending order:
# FIRE_INSUR_AREA: 0
# BUILDING_AREA: 0
# NO_OF_FLOOR: 0
# BUILDING_AGE: 0
# DISTICT_NAME: 0
# CLP: 0
# BUILDING_CONDITION_DESC: 18
# GARDEN: 7761
# LIFT: 7917
# EXERCISE_ROOM: 8326
# POOL: 8334
# STEAM_ROOM: 8478

# %%
df_new['BUILDING_CONDITION_DESC'].fillna('ธรรมดา', inplace=True)
df_new['STEAM_ROOM'].fillna('N', inplace=True)
df_new['LIFT'].fillna('N', inplace=True)
df_new['EXERCISE_ROOM'].fillna('N', inplace=True)
df_new['GARDEN'].fillna('N', inplace=True)
df_new['POOL'].fillna('N', inplace=True)

# %%
# Check for null values in each column
null_counts = df_new.isnull().sum()

# Sort the null_counts Series in descending order
sorted_null_counts = null_counts.sort_values()

# Display the column names and null counts in descending order
print("Column names and null counts in descending order:")
for column, null_count in sorted_null_counts.items():
    print(f"{column}: {null_count}")
# Out:
# Column names and null counts in descending order:
# LIFT: 0
# FIRE_INSUR_AREA: 0
# BUILDING_CONDITION_DESC: 0
# BUILDING_AREA: 0
# NO_OF_FLOOR: 0
# GARDEN: 0
# POOL: 0
# BUILDING_AGE: 0
# DISTICT_NAME: 0
# STEAM_ROOM: 0
# EXERCISE_ROOM: 0
# CLP: 0

# %%
list(set(df_new.dtypes.tolist()))
# Out:
# [dtype('float64'), dtype('int64'), dtype('O')]

# %%
from sklearn.preprocessing import OneHotEncoder

s = (df_new.dtypes == 'object')
object_cols = list(s[s].index)
print("Categorical variables:")
print(object_cols)
print('No. of. categorical features: ',
      len(object_cols))
# Out:
# Categorical variables:
# ['LIFT', 'BUILDING_CONDITION_DESC', 'GARDEN', 'POOL', 'DISTICT_NAME', 'STEAM_ROOM', 'EXERCISE_ROOM']
# No. of. categorical features:  7

# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd

# Assuming dataset_df and object_cols are defined
OH_encoder = OneHotEncoder(sparse_output=False)
OH_cols = pd.DataFrame(OH_encoder.fit_transform(df_new[object_cols]))
OH_cols.index = df_new.index
OH_cols.columns = OH_encoder.get_feature_names_out(object_cols)

df_final = df_new.drop(object_cols, axis=1)
df_final = pd.concat([df_final, OH_cols], axis=1)

# %%
print("Full train dataset shape is {}".format(df_final.shape))
# Out:
# Full train dataset shape is (30506, 95)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost
import math
from __future__ import division
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score

# %%
# Importing required libraries
import pandas as pd
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Assuming df_final is your DataFrame with features and target variable CLP
# Splitting the data into features (X) and target variable (y)
X = df_final.drop('CLP', axis=1)  # Features
y = df_final['CLP']  # Target variable

# Splitting dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Instantiate the XGBoost Regressor
xgb_regressor = XGBRegressor(random_state=42)

# Fit the model to the training data
xgb_regressor.fit(X_train, y_train)

# Predict on the test data
y_pred = xgb_regressor.predict(X_test)

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Percentage Error (MAPE): 11.73219068049194

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a function to plot scatter plot of actual vs predicted values
def plot_scatter(actual, predicted, model_name):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=actual, y=predicted, color='blue', alpha=0.5)
    plt.title(f'Actual vs. Predicted Values ({model_name})')
    plt.xlabel('Actual Price')
    plt.ylabel('Predicted Price')
    plt.xlim(0, 15000000)  # Set x-axis limits from 0 to 15,000,000
    plt.ylim(0, 15000000)  # Set y-axis limits from 0 to 15,000,000
    plt.gca().ticklabel_format(style='plain')  # Set tick labels without scientific notation
    plt.plot([0, 15000000], [0, 15000000], color='red', linestyle='--', alpha=0.5)  # Add diagonal line for perfect predictions
    plt.grid(True)
    plt.show()

# Plot scatter plot for each model
models = [xgb_regressor]  # Add other models if you have trained them
model_names = ['XGBRegressor']  # Adjust model names accordingly

for model, model_name in zip(models, model_names):
    predictions = model.predict(X_test)
    plot_scatter(y_test, predictions, model_name)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a function to plot distributions of actual and predicted values
def plot_distributions(actual, predicted, model_name):
    plt.figure(figsize=(10, 5))
    sns.histplot(actual, bins=100, color='blue', alpha=0.5, label='Actual Values of Price')
    sns.histplot(predicted, bins=100, color='orange', alpha=0.5, label='Predicted Values of Price')
    plt.legend()
    plt.title(f'Distribution of Actual vs. Predicted Values ({model_name})')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.ylim(0, )  # Set y-axis limits from 0 to 1,000,000
    plt.xlim(0, )  # Set x-axis limits from 0 to 1,500,000
    plt.gca().ticklabel_format(style='plain')  # Set tick labels without scientific notation
    plt.show()

# Plot distributions for each model
models = [xgb_regressor]  # Add other models if you have trained them
model_names = ['xgboost']  # Adjust model names accordingly

for model, model_name in zip(models, model_names):
    predictions = model.predict(X_test)
    plot_distributions(y_test, predictions, model_name)

# %%
import matplotlib as mpl

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New', size= 15)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'xgb' is your XGBoost model
feature_importances = xgb_regressor.feature_importances_

# Get the names of the features
feature_names = X_test.columns  # Assuming X_test is a pandas DataFrame

# Create a DataFrame with feature names and their corresponding importances
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df.head(10))  # Plotting top 10 features
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 10 Most Important Features')
plt.show()

# %%
# Importing required libraries
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# Assuming df_final is your DataFrame with features and target variable CLP
# Splitting the data into features (X) and target variable (y)
X = df_final.drop('CLP', axis=1)  # Features
y = df_final['CLP']  # Target variable

# Splitting dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Instantiate the KNN Regressor
knn_regressor = KNeighborsRegressor()

# Fit the model to the training data
knn_regressor.fit(X_train, y_train)

# Predict on the test data
y_pred = knn_regressor.predict(X_test)

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)
print("Mean Absolute Percentage Error (MAPE):", mape)
# Out:
# Mean Absolute Percentage Error (MAPE): 10.513626339361862

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a function to plot scatter plot of actual vs predicted values
def plot_scatter(actual, predicted, model_name):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=actual, y=predicted, color='blue', alpha=0.5)
    plt.title(f'Actual vs. Predicted Values ({model_name})')
    plt.xlabel('Actual Price')
    plt.ylabel('Predicted Price')
    plt.xlim(0, 15000000)  # Set x-axis limits from 0 to 15,000,000
    plt.ylim(0, 15000000)  # Set y-axis limits from 0 to 15,000,000
    plt.gca().ticklabel_format(style='plain')  # Set tick labels without scientific notation
    plt.plot([0, 15000000], [0, 15000000], color='red', linestyle='--', alpha=0.5)  # Add diagonal line for perfect predictions
    plt.grid(True)
    plt.show()

# Plot scatter plot for each model
models = [knn_regressor]  # Add other models if you have trained them
model_names = ['KNeighborsRegressor']  # Adjust model names accordingly

for model, model_name in zip(models, model_names):
    predictions = model.predict(X_test)
    plot_scatter(y_test, predictions, model_name)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a function to plot distributions of actual and predicted values
def plot_distributions(actual, predicted, model_name):
    plt.figure(figsize=(20, 8))
    sns.histplot(actual, bins=100, color='blue', alpha=0.5, label='Actual Values of Price')
    sns.histplot(predicted, bins=100, color='orange', alpha=0.5, label='Predicted Values of Price')
    plt.legend()
    plt.title(f'Distribution of Actual vs. Predicted Values ({model_name})')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.ylim(0, )  # Set y-axis limits from 0 to 1,000,000
    plt.xlim(0, )  # Set x-axis limits from 0 to 1,500,000
    plt.gca().ticklabel_format(style='plain')  # Set tick labels without scientific notation
    plt.show()

# Plot distributions for each model
models = [knn_regressor]  # Add other models if you have trained them
model_names = ['KNeighborsRegressor']  # Adjust model names accordingly

for model, model_name in zip(models, model_names):
    predictions = model.predict(X_test)
    plot_distributions(y_test, predictions, model_name)

# %%
# Importing required libraries
import pandas as pd
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import train_test_split

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# Assuming df_final is your DataFrame with features and target variable CLP
# Splitting the data into features (X) and target variable (y)
X = df_final.drop('CLP', axis=1)  # Features
y = df_final['CLP']  # Target variable

# Splitting dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Instantiate the Extra Trees Regressor
extra_trees = ExtraTreesRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
extra_trees.fit(X_train, y_train)

# Predict on the test data
y_pred = extra_trees.predict(X_test)

# Calculate MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)
print(f'Mean Absolute Percentage Error (MAPE): {mape:.2f}%')
# Out:
# Mean Absolute Percentage Error (MAPE): 9.59%

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a function to plot scatter plot of actual vs predicted values
def plot_scatter(actual, predicted, model_name):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=actual, y=predicted, color='blue', alpha=0.5)
    plt.title(f'Actual vs. Predicted Values ({model_name})')
    plt.xlabel('Actual Price')
    plt.ylabel('Predicted Price')
    plt.xlim(0, 15000000)  # Set x-axis limits from 0 to 15,000,000
    plt.ylim(0, 15000000)  # Set y-axis limits from 0 to 15,000,000
    plt.gca().ticklabel_format(style='plain')  # Set tick labels without scientific notation
    plt.plot([0, 15000000], [0, 15000000], color='red', linestyle='--', alpha=0.5)  # Add diagonal line for perfect predictions
    plt.grid(True)
    plt.show()

# Plot scatter plot for each model
models = [extra_trees]  # Add other models if you have trained them
model_names = ['ExtraTreesRegressor']  # Adjust model names accordingly

for model, model_name in zip(models, model_names):
    predictions = model.predict(X_test)
    plot_scatter(y_test, predictions, model_name)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a function to plot distributions of actual and predicted values
def plot_distributions(actual, predicted, model_name):
    plt.figure(figsize=(10, 5))
    sns.histplot(actual, bins=100, color='blue', alpha=0.5, label='Actual Values of Price')
    sns.histplot(predicted, bins=100, color='orange', alpha=0.5, label='Predicted Values of Price')
    plt.legend()
    plt.title(f'Distribution of Actual vs. Predicted Values ({model_name})')
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.ylim(0, )  # Set y-axis limits from 0 to 1,000,000
    plt.xlim(0, )  # Set x-axis limits from 0 to 1,500,000
    plt.gca().ticklabel_format(style='plain')  # Set tick labels without scientific notation
    plt.show()

# Plot distributions for each model
models = [extra_trees]  # Add other models if you have trained them
model_names = ['ExtraTreesRegressor']  # Adjust model names accordingly

for model, model_name in zip(models, model_names):
    predictions = model.predict(X_test)
    plot_distributions(y_test, predictions, model_name)

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Get feature importances
feature_importances = extra_trees.feature_importances_

# Get the names of the features
feature_names = X_train.columns  # Assuming X_train is a pandas DataFrame

# Create a DataFrame with feature names and their corresponding importances
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df.head(10))  # Plotting top 10 features
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 10 Most Important Features')
plt.show()
